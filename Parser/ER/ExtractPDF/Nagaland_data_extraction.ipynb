# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Dec 27 09:49:05 2017

@author: dhingratul
"""
import time
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import urllib
import sys
sys.path.insert(0, '../tools/')
import ssl
import requests
import wget
import os
import numpy as np
import pandas as pd

def download_file_W_nagaland(pdf_url, mdir, filename, flag=False):
    filename = mdir + filename
    ssl._create_default_https_context = ssl._create_unverified_context
    wget.download(pdf_url, filename)
    if os.stat(filename).st_size == 0:
        flag = 0
    else:
        flag = 1
    return flag


m_url = "http://ceonagaland.nic.in/DownloadERoll"
base_url = 'http://ceonagaland.nic.in/Downloads/FinalRoll2021/'
mdir = '../Nagaland/'

df = pd.read_csv('nagaland.csv')
len = df.shape[0]
for x in range(0,1858):
    pdf_name = df['filename'][x]
    i = int(pdf_name[2:5])
    j = int(pdf_name[9:12])
    print("\n", i, j)
    suffix = "{}/S17A{}P{}.pdf".format(i,i,j)
    url = base_url + suffix
    print(url)
    fid = suffix.replace("/", "_")
    try:
        flag = download_file_W_nagaland(url, mdir, fid)
        if flag == 0:
            with open("nagaland.txt", "a") as myfile:
                myfile.write(url + '\n')
    except urllib.error.HTTPError:
        print("Error")
        with open("nagaland.txt", "a") as myfile:
            myfile.write(url + '\n')
# Out:
#  21 1
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P1.pdf
#
#  21 2
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P2.pdf
#
#  21 3
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P3.pdf
#
#  21 4
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P4.pdf
#
#  21 5
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P5.pdf
#
#  21 6
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P6.pdf
#
#  21 7
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P7.pdf
#
#  21 8
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P8.pdf
#
#  21 9
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P9.pdf
#
#  21 10
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P10.pdf
#
#  21 11
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P11.pdf
#
#  21 12
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P12.pdf
#
#  21 13
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P13.pdf
#
#  21 14
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P14.pdf
#
#  21 15
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P15.pdf
#
#  21 16
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P16.pdf
#
#  21 17
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P17.pdf
#
#  21 18
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P18.pdf
#
#  21 19
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P19.pdf
#
#  21 20
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P20.pdf
#
#  21 21
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P21.pdf
#
#  21 22
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P22.pdf
#
#  21 23
# http://ceonagaland.nic.in/Downloads/FinalRoll2021/21/S17A21P23.pdf
