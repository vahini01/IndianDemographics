# %%
# !pip install BeautifulSoup4

# %%
# path
AIEEE = '../../../jalend/aieeedata/'
AIEEE_2004 = AIEEE+'2004.p' # No caste
AIEEE_2006 = AIEEE+'2006.p' # No caste
AIEEE_2008 = AIEEE+'2008.p' # No caste
AIEEE_2009 = AIEEE+'2009.p' # extracting
AIEEE_2010 = AIEEE+'2010.p' # extracting
AIEEE_2011 = AIEEE+'2011.p'

# %%
import pickle
# Reading a pickle file
ai_04 = []
with (open(AIEEE_2004, "rb")) as openfile:
    count = 0
    while True:
        try:
            ai_04.append(pickle.load(openfile))
            count += 1
            if(count == 3) :
                break
    #             break
        except EOFError:
                break

# %%
with (open(AIEEE_2006, "rb")) as openfile:
    ai_06 = pickle.load(openfile)

# %%
with (open(AIEEE_2008, "rb")) as openfile:
    ai_08 = pickle.load(openfile)

# %%
with (open(AIEEE_2009, "rb")) as openfile:
    ai_09 = pickle.load(openfile)

# %%
with (open(AIEEE_2011, "rb")) as openfile:
    ai_11 = pickle.load(openfile)

# %%
ai_11.keys()
# Out:
# dict_keys([24104356, 23009005, 23808198, 26214060, 28401114, 22110386, 20403039, 25618487, 24205314, 24725465, 21829515, 26614178, 28003332, 23805219, 23412153, 23320981, 20604084, 22008244, 26102430, 26705706, 26705654, 27301048, 27709205, 23209621, 28119939, 28112478, 25907086, 27902648, 24109784, 20334404, 22205309, 27806843, 26301106, 27202095, 27102077, 21808385, 24206356, 25610669, 21217654, 20510839, 24612004, 24725600, 23501486, 27406462, 26304004, 22402495, 22902601, 22404044, 23003431, 26244837, 20900979, 25031148, 22406555, 24500756, 22506509, 26251767, 26251200, 28002309, 28101469, 20343788, 25903810, 24107800, 24119761, 22009463, 27511852, 27921675, 22000303, 20328044, 27502270, 25028826, 24505786, 26405682, 27512694, 24303086, 23101068, 22200985, 20312140, 27400784, 21510949, 22602753, 24414402, 27412226, 22002238, 24602534, 27514229, 21824708, 23324113, 27005016, 22401322, 25613390, 20703126, 27700732, 27500686, 21508929, 28500107, 22023179, 22804565, 21412827, 2050429
# ...

# %%
ai_08.keys()
# Out:
# dict_keys([22103460, 20606667, 28023820, 27712778, 21303875, 26114365, 27100475, 28204919, 20602714, 26603861, 28401112, 21683512, 24200482, 27908383, 20906474, 24307634, 21678890, 26131577, 23115079, 21808686, 26601146, 24709694, 23903280, 25805114, 23110899, 23700663, 22002411, 27803626, 28101188, 28201261, 21645491, 21810273, 20909137, 24606130, 21503034, 27602659, 24228685, 25305632, 26801995, 21680315, 23301946, 28400796, 28201774, 24613953, 23112884, 27107631, 27811992, 21679196, 20607123, 28511315, 25300523, 23003812, 24218456, 23812175, 23002455, 21624797, 21906596, 25602750, 28515396, 28115485, 27400565, 21816702, 28106437, 28104349, 24225807, 21670430, 23207429, 23702118, 25315851, 21628800, 27802090, 20505880, 28113137, 24710792, 22005905, 28118955, 23905530, 21509030, 24211008, 21501491, 26802052, 27707640, 24007565, 26129738, 27807582, 26609848, 28112736, 22802210, 26608383, 26600637, 21667709, 20601362, 21817952, 23314558, 28507071, 21633751, 28104658, 26605453, 2670088
# ...

# %%
ai_06.keys()
# Out:
# dict_keys([27400413, 23307553, 27801315, 21657062, 20602570, 23410992, 23003529, 28510463, 24606238, 21637976, 26400292, 24800133, 22303157, 26615461, 24000931, 20905636, 20800223, 20200922, 22600686, 21635363, 27103216, 24500927, 22801135, 24201543, 20202882, 28003873, 24712562, 21647090, 28303547, 26109326, 25802121, 24900026, 21600262, 26610940, 22400187, 21658544, 24509135, 22203391, 26000511, 27804972, 26607915, 21621897, 27903737, 20306897, 21642459, 28118217, 22601542, 26112928, 24204901, 22201065, 23700927, 24300349, 27300839, 20906783, 20400851, 26603984, 23903052, 25309017, 23105676, 27813902, 23407404, 21632756, 26600459, 20904018, 28118451, 27812431, 28201615, 27705606, 22300494, 26700614, 20503950, 25401017, 26612755, 28501875, 21802722, 22000733, 24804369, 21403451, 28202388, 26604729, 24301048, 25302510, 21633209, 23803690, 28119252, 21902963, 28107767, 23202798, 26607114, 23000421, 22201796, 21101028, 21625483, 21405952, 28002128, 24501016, 25305196, 24901380, 2790287
# ...

# %%
ai_04[0].keys()
# Out:
# dict_keys([23404119, 27400064, 21302689, 21403036, 21624526, 24300586, 21402970, 21807358, 25101509, 28502177, 23301967, 27600880, 21400941, 26101331, 27407483, 21624154, 29003486, 28801692, 27402877, 28104056, 25301994, 24203902, 22103564, 22101668, 27800236, 28600128, 28900178, 23706887, 26905363, 21306022, 23704895, 21630110, 29002783, 20800224, 21300322, 24000596, 26201017, 27105724, 24800447, 24100189, 20901785, 21401694, 22602236, 23611012, 28800696, 26910882, 22303144, 23603476, 21807496, 29011596, 26801521, 22501024, 25500316, 21700056, 25101776, 20502203, 21805282, 29007394, 24900985, 21637976, 24802592, 27700079, 28900020, 23603182, 25205109, 25303138, 24704685, 28100983, 23612752, 20601545, 20309251, 21637149, 22000259, 23500481, 25003014, 26501825, 25002602, 21620115, 21805481, 20200969, 25004221, 25308903, 24203892, 27000336, 29006248, 22801131, 20307398, 21806501, 21303303, 24802545, 20602503, 27106314, 24704922, 25308757, 23411486, 25205814, 24705652, 20602470, 2180344
# ...

# %%
roll = ai_11[24602534]

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(roll, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <style media="print" type="text/css">
#    .dontprintme { display: none; }
#   </style>
#   <script language="javascript">
#    <!--
# function newwin()
# {
# if (self != top)
# top.location.href="cbseaieee.htm";
# }
# function visitSite(url){
# mywin=window.open("","goidisplaywin","width=600,height=350,screenX=100,screenY=0,scrollbars=yes,menubar=yes,resizable=yes,status=yes,toolbar=yes,directories=no,location=yes");
# mywin.location.href=url;
# mywin.focus();
# }
# //-->
#   </script>
#   <title>
#    CBSE - ALL INDIA ENGINEERING / ARCHITECTURE ENTRANCE EXAMINATION 2011
#   </title>
#  </head>
#  <body alink="#3333cc" bgcolor="#ffffff" leftmargin="0" link="#3333cc" marginheight="0" marginwidth="0" onload="newwin()" text="#000000" topmargin="0" vlink="#3333cc">
#   <table bgcolor="#373abe" border="0" cellpadding="0" cellspacing="0" width="100%">
#    <tr align="left" valign="top">
#     <td width="5%">
# ...
